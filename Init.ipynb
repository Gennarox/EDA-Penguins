# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting pip
#   Downloading pip-24.1.2-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.4 MB/s eta 0:00:00
# Collecting palmerpenguins==0.1.4
#   Downloading palmerpenguins-0.1.4-py3-none-any.whl (17 kB)
# Collecting numpy==1.23.4
#   Downloading numpy-1.23.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 55.3 MB/s eta 0:00:00
# Collecting pandas==1.5.1
#   Downloading pandas-1.5.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 71.8 MB/s eta 0:00:00
# Collecting seaborn==0.12.1
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 KB 25.7 MB/s eta 0:00:00
# Collecting matplotlib==3.6.0
#   Downloading matplotlib-3.6.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 73.4 MB/s eta 0:00:00
# Collecting empiricaldist==0.6.7
#   Downloading empiricaldist-0.6.7.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting statsmodels==0.13.5
#   Downloading statsmodels-0.13.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 86.3 MB/s eta 0:00:00
# Collecting scikit-learn==1.1.2
#   Downloading scikit_learn-1.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 32.5 MB/s eta 0:00:00
# Collecting pyjanitor==0.23.1
#   Downloading pyjanitor-0.23.1-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.7/147.7 KB 12.9 MB/s eta 0:00:00
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 KB 50.8 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.1
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 36.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.1/301.1 KB 34.1 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 75.6 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 65.9 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-24.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 KB 10.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.1 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 KB 7.0 MB/s eta 0:00:00
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 KB 19.9 MB/s eta 0:00:00
# Collecting scipy>=1.3
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 33.5 MB/s eta 0:00:00
# Collecting joblib>=1.0.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 KB 40.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting pandas-flavor
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Collecting natsort
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Collecting multipledispatch
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Collecting stdlib_list
#   Downloading stdlib_list-0.10.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 KB 17.0 MB/s eta 0:00:00
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting xarray
#   Downloading xarray-2023.1.0-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 KB 64.1 MB/s eta 0:00:00
# Building wheels for collected packages: empiricaldist, session-info
#   Building wheel for empiricaldist (setup.py): started
#   Building wheel for empiricaldist (setup.py): finished with status 'done'
#   Created wheel for empiricaldist: filename=empiricaldist-0.6.7-py3-none-any.whl size=11957 sha256=1383aaac7bcb31ae4baf4b7d569ecab2239c76ef2795abdb56765a8c107e86ef
#   Stored in directory: /root/.cache/pip/wheels/5d/f1/db/255568cadde52e7abae2955e024ccfafedde836254f210ee12
#   Building wheel for session-info (setup.py): started
#   Building wheel for session-info (setup.py): finished with status 'done'
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8048 sha256=0aafba5fae0a1bd3ab9307d5388465f73aa7ee1b76b172cbce275b7d92d4fabd
#   Stored in directory: /root/.cache/pip/wheels/5c/1b/4d/111d73980c5c6a8e5e5905a19eccc34296cb359cac54c6c5b9
# Successfully built empiricaldist session-info
# Installing collected packages: pytz, multipledispatch, empiricaldist, threadpoolctl, stdlib_list, six, pyparsing, pip, pillow, packaging, numpy, natsort, kiwisolver, joblib, fonttools, cycler, session-info, scipy, python-dateutil, patsy, contourpy, scikit-learn, pandas, matplotlib, xarray, statsmodels, seaborn, palmerpenguins, pandas-flavor, pyjanitor
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# snowflake-connector-python 2.8.0 requires cryptography<37.0.0,>=3.1.0, but you have cryptography 38.0.4 which is incompatible.
# google-cloud-spanner 3.36.0 requires sqlparse>=0.4.4, but you have sqlparse 0.4.3 which is incompatible.
# botocore 1.34.59 requires urllib3<1.27,>=1.25.4; python_version < "3.10", but you have urllib3 1.24.3 which is incompatible.
# Successfully installed contourpy-1.1.1 cycler-0.12.1 empiricaldist-0.6.7 fonttools-4.53.1 joblib-1.4.2 kiwisolver-1.4.5 matplotlib-3.6.0 multipledispatch-1.0.0 natsort-8.4.0 numpy-1.23.4 packaging-24.1 palmerpenguins-0.1.4 pandas-1.5.1 pandas-flavor-0.6.0 patsy-0.5.6 pillow-10.4.0 pip-24.1.2 pyjanitor-0.23.1 pyparsing-3.1.2 python-dateutil-2.9.0.post0 pytz-2024.1 scikit-learn-1.1.2 scipy-1.10.1 seaborn-0.12.1 session-info-1.0.0 six-1.16.0 statsmodels-0.13.5 stdlib_list-0.10.0 threadpoolctl-3.5.0 xarray-2023.1.0
# WARNING: Target directory /opt/conda/lib/python3.8/site-packages/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/conda/lib/python3.8/site-packages/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/conda/lib/python3.8/site-packages/six-1.16.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /opt/conda/lib/python3.8/site-packages/pip already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 22.0.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3d6d22e0-1a39-4033-9c0b-5100459960b8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
